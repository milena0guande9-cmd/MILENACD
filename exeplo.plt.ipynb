# %%
import pandas as pd
import matplotlib.pyplot as plt
dados={
    "idade":[20,23,32,33,34,35],
    "Rendimento":[500,1000,1500,2000,2300,2500]
}
df = pd.DataFrame(dados)
df

print(df.corr())

plt.scatter(df["idade"], df["Rendimento"])
plt.show()
# Out:
#                idade  Rendimento
# idade       1.000000    0.954585
# Rendimento  0.954585    1.000000
