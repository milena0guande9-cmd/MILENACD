# %%
nome = "Milena Cumbane"
idade = 21
curso = "Informatica"
cidade = "Maputo"

print(nome)
print(idade)
print(curso)
print(cidade)

notas = [15, 14, 13, 16, 12]
print(notas)
print(max(notas))
print(min(notas))

for nota in notas:
    print(nota)

def media_notas(notas):
    media = sum(notas) / len(notas)
    return media
# Out:
# Milena Cumbane
# 21
# Informatica
# Maputo
# [15, 14, 13, 16, 12]
# 16
# 12
# 15
# 14
# 13
# 16
# 12
