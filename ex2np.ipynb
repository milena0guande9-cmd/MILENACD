# %%
import pandas as pd

dados = {
    "Estudante": ["Ana", "Maria", "Paula", "Joao"],
    "Curso": ["Informatica", "Direito", "Biologia", "Engenharia"],
    "Idade": [17, 20, 19, 18],
    "Nota": [16, 13, 14, 15]
}

df = pd.DataFrame(dados)
df["Estudante"]
len(df)

df[df["Nota"] > 14]
df[df["Nota"] > 14]["Estudante"]

df_ordenado = df.sort_values(by="Nota", ascending=False)
df_ordenado

melhor = df.loc[df["Nota"].idxmax()]
print(melhor)
# Out:
# Estudante            Ana
# Curso        Informatica
# Idade                 17
# Nota                  16
# Name: 0, dtype: object
