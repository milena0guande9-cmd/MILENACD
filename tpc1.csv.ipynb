# %%
import os
print(os.getcwd())

import pandas as pd
df = pd.read_csv("C:/Users/Milena/Documents/dados.csv")
df.head()
df.isnull().sum()
df[df.isnull().any(axis=1)]
df = df.drop_duplicates()

df.to_csv("alunos_limpo.csv", index=False)
df
# Out:
# C:\Users\Milena
#       nome  idade        curso  nota
# 0      Ana   15.0  Informatica    12
# 1     Joao   17.0     Biologia    12
# 2   Manuel   16.0      Direito    13
# 4  Ronaldo   19.0     Desporto    11
# 5    Maria    NaN    Geografia    16
